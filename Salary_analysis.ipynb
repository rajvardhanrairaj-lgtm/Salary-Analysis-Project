# %% [markdown]
# # Salary Analysis Project

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import os

os.listdir(r"C:\Users\Raj Vardhan Rai\OneDrive\Desktop\Salary analysis")
# Out:
# ['Salary_data.csv.csv']

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd

df = pd.read_csv("Salary_data.csv.csv")
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.tail()
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
df.shape
# Out:
# (6704, 6)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6702 non-null   float64
#  1   Gender               6702 non-null   object
#  2   Education Level      6701 non-null   object
#  3   Job Title            6702 non-null   object
#  4   Years of Experience  6701 non-null   float64
#  5   Salary               6699 non-null   float64
# dtypes: float64(3), object(3)
# memory usage: 314.4+ KB

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(17)

# %%
df.duplicated().sum()
# Out:
# np.int64(4912)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female', nan, 'Other'], dtype=object)

# %%
df["Education Level"].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      969
# Female    815
# Other       7
# Name: count, dtype: int64

# %%
df["Job Title"].nunique()
# Out:
# 193

# %%
df.shape
# Out:
# (1792, 6)

# %%
df[df.duplicated()].head(10)
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Education Level, Job Title, Years of Experience, Salary]
# Index: []

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1792, 6)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Data Exloration

# %%
df["Salary"].mean()
# Out:
# np.float64(113177.28579418345)

# %%
df["Salary"].max()
# Out:
# 250000.0

# %%
df["Salary"].min()
# Out:
# 350.0

# %%
df["Salary"].median()
# Out:
# 110000.0

# %% [markdown]
# ## Filtering

# %%
high = df[df["Salary"] > 100000]

print(high)
# Out:
#        Age  Gender    Education Level                         Job Title  \
# 2     45.0    Male                PhD                    Senior Manager
# 4     52.0    Male           Master's                          Director
# 6     42.0  Female           Master's                   Product Manager
# 9     38.0    Male                PhD                  Senior Scientist
# 11    48.0  Female         Bachelor's                        HR Manager
# ...    ...     ...                ...                               ...
# 6613  51.0  Female    Master's Degree  Senior Product Marketing Manager
# 6615  49.0  Female                PhD             Director of Marketing
# 6618  46.0    Male    Master's Degree                 Marketing Manager
# 6620  42.0    Male  Bachelor's Degree         Content Marketing Manager
# 6623  43.0  Female    Master's Degree         Digital Marketing Manager
#
#       Years of Experience    Salary
# 2                    15.0  150000.0
# ...

# %%
female = df[df["Gender"]=="Female"]

# %%
exp = df[df["Years of Experience"]>10]

# %% [markdown]
# ## Sorting Groupby

# %%
df.groupby("Gender")["Salary"].mean()
# Out:
# Gender
# Female    107294.798526
# Male      118037.526370
# Other     125819.000000
# Name: Salary, dtype: float64

# %%
df.groupby("Education Level")["Salary"].mean()
# Out:
# Education Level
# Bachelor's            92249.427481
# Bachelor's Degree     90574.001976
# High School           45435.981818
# Master's             139303.278689
# Master's Degree      124185.726457
# PhD                  161062.941176
# phD                  120000.000000
# Name: Salary, dtype: float64

# %%
df.groupby("Job Title")["Salary"].mean().sort_values(ascending=False).head(10)
# Out:
# Job Title
# CEO                            250000.0
# Chief Technology Officer       250000.0
# Chief Data Officer             220000.0
# VP of Finance                  200000.0
# Director of Data Science       200000.0
# Director                       200000.0
# Operations Director            190000.0
# VP of Operations               190000.0
# Director of Human Resources    187500.0
# Human Resources Director       180000.0
# Name: Salary, dtype: float64

# %%
df.groupby("Years of Experience")["Salary"].mean()
# Out:
# Years of Experience
# 0.0      37021.150000
# 0.5      35000.000000
# 1.0      44519.952381
# 1.5      36395.454545
# 2.0      54620.211921
# 3.0      66083.845070
# 4.0      77462.846774
# 5.0      92566.961538
# 6.0     107234.228571
# 7.0     110350.576087
# 8.0     114675.361905
# 9.0     127693.082353
# 10.0    123998.545455
# 11.0    142040.180556
# 12.0    143873.512500
# 13.0    144199.903226
# 14.0    155265.206349
# 15.0    154780.957447
# 16.0    170104.338983
# 17.0    171967.363636
# 18.0    173300.369565
# 19.0    174428.772727
# 20.0    174268.806452
# 21.0    177124.666667
# 22.0    174880.086957
# 23.0    183030.235294
# 24.0    195921.222222
# 25.0    181076.000000
# 26.0    188411.400000
# 27.0    186353.800000
# 28.0    188585.625000
# 29.0    181445.000000
# 30.0    171717.800000
# 31.0    187256.750000
# 32.0    192682.333333
# 33.0    186400.666667
# 34.0    188651.000000
# Name: Salary, dtype: float64

# %%
df.groupby("Education Level")["Salary"].mean().sort_values(ascending=False)
# Out:
# Education Level
# PhD                  161062.941176
# Master's             139303.278689
# Master's Degree      124185.726457
# phD                  120000.000000
# Bachelor's            92249.427481
# Bachelor's Degree     90574.001976
# High School           45435.981818
# Name: Salary, dtype: float64

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["Salary"], bins=20)

plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# # Employee by gender

# %%
import seaborn as sns

sns.countplot(data=df, x="Gender")

plt.title("Employees by Gender")

plt.show()

# %% [markdown]
# # Salary by gender

# %%
sns.barplot(data=df, x="Gender", y="Salary")

plt.title("Average Salary by Gender")

plt.show()

# %% [markdown]
# # Salary vs Experience (Scatter Plot)

# %%
plt.figure(figsize=(8,5))

plt.scatter(df["Years of Experience"], df["Salary"])

plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")

plt.show()

# %% [markdown]
# # Salary box plot

# %%
sns.boxplot(x=df["Salary"])

plt.title("Salary Box Plot")

plt.show()

# %% [markdown]
# # Average salary by education level

# %%
plt.figure(figsize=(8,5))

education_salary = df.groupby("Education Level")["Salary"].mean().sort_values()

education_salary.plot(kind="bar")

plt.title("Average Salary by Education Level")
plt.xlabel("Education Level")
plt.ylabel("Average Salary")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(6,4))

numeric_df = df.select_dtypes(include="number")

sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
numeric_df.corr()
# Out:
#                           Age  Years of Experience    Salary
# Age                  1.000000             0.936040  0.766758
# Years of Experience  0.936040             1.000000  0.818732
# Salary               0.766758             0.818732  1.000000

# %% [markdown]
# # Business Insights
# The average salary is ₹113,177.
# Employees with a PhD have the highest average salary (₹161,062.94).
# CEO is the highest-paying job title with an average salary of ₹250,000.
# The dataset contains 193 unique job titles.
# Salary generally increases with years of experience.
# The dataset contained 17 missing values.

# %% [markdown]
# # Conclusion
# This project analyzed employee salary data using Python.
#
# The analysis included:
#
# Data loading using Pandas
# Data cleaning
# Exploratory Data Analysis (EDA)
# Data visualization with Matplotlib and Seaborn
# Correlation analysis
# Business insights
# The analysis shows that employees with higher education and more experience generally earn higher salaries.

# %%
df.to_csv("Cleaned_Salary_Data.csv", index=False)

# %% [markdown]
# # Salary Analysis Project

# %% [markdown]
# ## Tools Used
# - Python
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - JupyterLab
#
# ## Project Objective
# Analyze employee salary data to identify salary trends based on education, experience, gender, and job title.
#
# ## Key Findings
# - Average Salary: ₹113,177
# - Highest Paying Education: PhD
# - Highest Paying Job Title: CEO
# - Salary increases with experience.
#
# ## Skills Demonstrated
# - Data Cleaning
# - Data Analysis
# - Data Visualization
# - Correlation Analysis

# %% [markdown]
# # Salary Analysis Project
#
# ## Tools Used
# - Python
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - JupyterLab
#
# ## Project Objective
# Analyze employee salary data to identify salary trends based on education, experience, gender, and job title.
#
# ## Key Findings
# - Average Salary: ₹113,177
# - Highest Paying Education: PhD
# - Highest Paying Job Title: CEO
# - Salary increases with experience.
#
# ## Skills Demonstrated
# - Data Cleaning
# - Data Analysis
# - Data Visualization
# - Correlation Analysis

# %%
df.to_csv("Cleaned_Salary_Data.csv", index=False)
